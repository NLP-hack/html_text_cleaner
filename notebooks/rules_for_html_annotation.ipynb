# %%
import re
import pandas as pd

# %%
data_raw = pd.read_csv('raw_labels_50.csv')
data_target = pd.read_csv('true_labels_50.csv')

# %%
data_raw.head()
# Out:
#                                 Неправильный вариант
# 0  Этапы отбора:1. Подача заявок (до 19 июня);2. ...
# 1  По всем вопросам вы можете обращаться по эл. п...
# 2  Некоторые из волонтерских задач:Привлечение за...
# 3  возраст кандидата не менее 18 лет (на момент п...
# 4  Сроки привлечения волонтеров: с 29 августа по ...

# %%
class HTMLAnnotator:

  def _base_formatting(self, text):
    text = re.sub(r'(?<=\n)"|(?<=\n)\n*|&nbsp', r'', text)
    text = re.sub(r':((?=(\d\.))|(?!(\n| |\d)))', r':\n', text)
    text = re.sub(r';(?!\n)', r';\n', text)
    text = re.sub(r'(\d|[а-я]|[^\w\s"«])([А-Я])', r'\1 \2', text)
    return text

  def _make_list_titles(self, text):
    text = re.sub(r'(.*?:(?=\n))', r'<p><b>\1</b></p>', text)
    return text

  def _make_lists(self, text):
    text = re.sub(r'(.*?;)', r'  <li>\1</li>', text)
    text = re.sub(r'(?<=(</p>\n))([\s\S]*)(?=(<p>)*)', r'<ul>\n\2\n</ul>', text)
    text = re.sub(r'(?<=(</li>\n))(.*)(?=(\n</ul>))', r'  <li>\2</li>', text)
    return text

  def _make_paragraphs(self, text):
    text = re.sub(r'(?<=\n)([^<]*)(?=\n)', r'<p>\1</p>', text)
    return text

  def _post_processing(self, text):
    text = re.sub(r'<p></p>', r'', text)
    return text

  def __call__(self, text):
    text = self._base_formatting(text)
    text = self._make_list_titles(text)
    text = self._make_lists(text)
    text = self._make_paragraphs(text)
    text = self._post_processing(text)
    return text

# %%
annotator = HTMLAnnotator()

# %%
data_annotated = data_raw['Неправильный вариант'].apply(annotator)

# %%
data_target['Размеченный вариант'] = data_annotated

# %%
data_target
# Out:
#                                    Правильный вариант  \
# 0   <ul>\n  <li><b>Этапы отбора:</b></li>\n  <li>1...
# 1   <p>По всем вопросам вы можете обращаться по эл...
# 2   <p>Некоторые из волонтерских задач:</p>\n<ol>\...
# 3   <p><b>Обязательными требованиями к волонтерам ...
# 4   <p><b>Сроки привлечения волонтеров:</b> с 29 а...
# 5   <ul>\n  <li></li>\n</ul>\n<p>По всем вопросам ...
# 6   <p><b>Регистрируйся на портале DOBRO.ru!</b></...
# 7   <p>Климатический урок разработан в двух вариан...
# 8   <p>\n<br>\n<b>Приглашаем волонтеров:</b>\n</p>...
# 9   <ul>\n  <li>опыт в бумажную личную книжку воло...
# 10  <p></p>\n<p><b>Каждый волонтёр получит:</b></p...
# 11  <p>Особенностями волонтерской программы в этом...
# 12  <p><b>Информация о событии:</b></p>\n<ul>\n  <...
# 13  <ul>\n  <li><h3>Основные преимущества программ...
# 14  <p>Приглашаем волонтеров принять участие в пом...
# 15  <ul>\n  <li>одиноким пенсионерам</li>\n  <li>м...
# 16  <p>Сервисы волонтеров:</p>\n<ul>\n  <li>экипир...
# 17  <p>Задачи волонтеров фестиваля:</p>\n<ul>\n  <...
# 18  <p>Мы набираем волонтеров на самое молодежное ...
# 19  <p>Кто нужен:</p>\n<ul>\n  <li>ответственные л...
# 20  <p>Присоединяйся к команде волонтёров оркестро...
# 21  <ul>\n  <li>Требования к волонтёрам:</li>\n  <...
# 22  <p><b>Даты проведения мероприятия:</b></p>\n<u...
# 23  <p>\n  <span>Задачи :</span>\n</p>\n<ul>\n  <l...
# 24  <p>Помощь в проведении Масштабного бегового со...
# 25  <p>Если ты внимательный и умеешь работать в MS...
# 26  <p>Чтобы стать волонтером Волонтерского центра...
# 27  <p>Основные темы программы:</p>\n<ul>\n  <li>п...
# 28  <p>ММП "КАЛЯЗИН. КУЛЬТУРА"</p>\n<p>Муниципальн...
# 29  <p><b>Что нужно будет делать:</b></p>\n<ul>\n ...
# 30  <p>Дети:</p>\n<ul>\n  <li>разного возраста (от...
# 31  <p>Формат акции рассчитан на две возрастные ка...
# 32  <p><b>В ходе лекций будет обсуждено множество ...
# 33  <p><strong>Условия для волонтеров:</strong></p...
# 34  <p>Задачи:</p>\n<ul>\n    <li>воспитание уваже...
# 35  <p>📍 Основные функции волонтеров:</p>\n<p>1.Уч...
# 36  <p>Благодаря этому:</p>\n<ul>\n    <li>ежегодн...
# 37  <p><b>Каждый день с 16 до 19:30 необходима пом...
# 38  <ul>\n    <li>2 июля 2022 года в Железногорске...
# 39  <p>Цели данного профилактического мероприятия:...
# 40  <p><b>Финансовые и технические условия участия...
# 41  <p>Это будет 2 дня:</p>\n<ul>\n  <li>Доступног...
# 42  <p><br><b>Волонтеры</b> будут задействованы в ...
# 43  <p><b>Обязательными требованиями к волонтерам ...
# 44  <p>Задачи волонтеров фестиваля:</p>\n<ul>\n  <...
# 45  <p>Цели:</p>\n<ul>\n  <li>Расчистить территори...
# 46  <p>При себе иметь:</p>\n<ul>\n  <li>Перчатки</...
# 47  <p><b>В рамках вебинара:</b></p>\n<ul>\n  <li>...
# 48  <p><b>Каждый волонтёр получит:</b></p>\n<ul>\n...
# 49  <ul>\n  <li><b>21 июня 2022г. с 16:00-17:00</b...
#
#                                   Размеченный вариант
# 0   <p><b>Этапы отбора:</b></p>\n<ul>\n  <li>1. По...
# 1   По всем вопросам вы можете обращаться по эл. п...
# 2   <p><b>Некоторые из волонтерских задач:</b></p>...
# 3     <li>возраст кандидата не менее 18 лет (на мо...
# 4   <p><b>Сроки привлечения волонтеров: с 29 авгус...
# 5   По всем вопросам вы можете обращаться по эл. п...
# 6   Регистрируйся на портале DOBRO.ru!\n<p>До встр...
# 7   <p><b>Климатический урок разработан в двух вар...
# 8   <p><b>Приглашаем волонтеров:</b></p>\n<ul>\n<p...
# 9     <li>опыт в бумажную личную книжку волонтера ...
# 10  <p><b>Каждый волонтёр получит:</b></p>\n<ul>\n...
# 11  <p><b>Особенностями волонтерской программы в э...
# 12  <p><b>Информация о событии:</b></p>\n<ul>\n  <...
# 13  <p><b>Основные преимущества программы:</b></p>...
# 14  <p><b>Приглашаем волонтеров принять участие в ...
# 15  - одиноким пенсионерам\n<p>- маломобильным гра...
# 16  <p><b>Сервисы волонтеров:</b></p>\n<ul>\n  <li...
# 17  <p><b>Задачи волонтеров фестиваля:</b></p>\n<u...
# 18    <li>Мы набираем волонтеров на самое молодежн...
# 19  <p><b>Кто нужен:</b></p>\n<ul>\n<p>ответственн...
# 20  <p><b>Присоединяйся к команде волонтёров оркес...
# 21  <p><b>Требования к волонтёрам:</b></p>\n<ul>\n...
# 22  Даты проведения мероприятия:21 мая - Главный х...
# 23  <p><b>Задачи :</b></p>\n<ul>\n<p>сформировать ...
# 24  "Помощь в проведении Масштабного бегового собы...
# 25  Если ты внимательный и умеешь работать в MS Of...
# 26  Чтобы стать волонтером Волонтерского центра РГ...
# 27  <p><b>Основные темы программы:</b></p>\n<ul>\n...
# 28  <p><b>"ММП ""КАЛЯЗИН. КУЛЬТУРА""",,"Муниципаль...
# 29  Что нужно будет делать: \n  <li>присматривать ...
# 30  <p><b>Дети:</b></p>\n<ul>\n  <li>разного возра...
# 31  <p><b>Формат акции рассчитан на две возрастные...
# 32  <p><b>В ходе лекций будет обсуждено множество ...
# 33  <p><b>Условия для волонтеров:</b></p>\n<ul>\n ...
# 34    <li>Задачи: воспитание уважения и почтительн...
# 35  <p><b>📍 Основные функции волонтеров:</b></p>\n...
# 36  <p><b>Благодаря этому:</b></p>\n<ul>\n<p>ежего...
# 37  <p><b>Каждый день с 16 до 19:30 необходима пом...
# 38  2 июля 2022 года в Железногорске Красноярского...
# 39  <p><b>Цели данного профилактического мероприят...
# 40  <p><b>Финансовые и технические условия участия...
# 41  <p><b>Это будет 2 дня:</b></p>\n<ul>\n  <li>;<...
# 42  <p><b>Волонтеры будут задействованы в работе с...
# 43    <li>возраст кандидата не менее 18 лет (на мо...
# 44  <p><b>Задачи волонтеров фестиваля:</b></p>\n<u...
# 45  <p><b>Цели:</b></p>\n<ul>\n<p>Расчистить терри...
# 46  <p><b>При себе иметь:</b></p>\n<ul>\n<p>Перчат...
# 47  <p><b>В рамках вебинара:</b></p>\n<ul>\n<p>лек...
# 48  <p><b>Каждый волонтёр получит:</b></p>\n<ul>\n...
# 49    <li>"21 июня 2022г. с 16:00-17:00 на Братско...
